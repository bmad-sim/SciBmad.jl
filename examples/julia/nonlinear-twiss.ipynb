# %% [markdown]
# # Nonlinear Twiss
# This Jupyter notebook introduces SciBmad's parametric nonlinear normal form routines, with the goal of familiarizing users with Truncated Power Series Algebra (TPSA) methods in accelerator physics. Various "nonlinear Twiss" calculations are made using the Electron Storage Ring of the Electron-Ion Collider. E.g., we will compute the beta function as a Taylor series in the momentum deviation $\delta$, and can also do so as a Taylor series in variations of some parameters, e.g. sextupole strengths.
#
# Map-based perturbation theory is an approach to perturbation theory introduced by Dragt and Finn, and developed in great detail for accelerator physics applications by Forest back in the early 90s. It is the only fully general and self consistent way to compute all such important quantities of the map, without any approximations up to the truncation order of the Taylor series. *All* quantities computed by SciBmad use this most powerful and general formalism.

# %%
using SciBmad
using CairoMakie # Plotting package
set_theme!(theme_latexfonts()) # Set plotting package theme to LaTeX

# %%
include("../../lattices/esr-v6.3.1.jl") # ESR lattice in lattices directory of SciBmad repo
# Out:
# Beamline:
#  species_ref = electron
#  pc_ref = 1.784626263654482e10
#
#   Index   Name      Kind         s [m]                L [m]
#   1       IP6       Marker       0                    0.0f0
#   2       DRIFT0    Drift        0.0f0                5.3
#   3       Q1ER_6    Quadrupole   5.3                  1.8
#   4       DRIFT1    Drift        7.1                  0.5
#   5       Q2ER_6    Quadrupole   7.6                  1.4
#   6       DRIFT2    Drift        9.0                  7.74999999999994
#   7       D2ER_6    SBend        16.74999999999994    5.500091667736123
#   8       DRIFT3    Drift        22.25009166773606    19.81459999999994
#   9       SQ3ER_6   Quadrupole   42.064691667736      0.25
#   10      DRIFT4    Drift        42.314691667736      0.15000000000000568
#   11      Q3ER_6    Quadrupole   42.464691667736005   0.6
#   12      DRIFT5    Drift        43.06469166773601    3.5
#   13      SQ4ER_6   Quadrupole   46.56469166773601    0.25
# ...

# %% [markdown]
# Let's start by just calling `twiss`:

# %%
tw = twiss(ring)
# Out:
# Twiss:
# summ:
#  q1     = 48.07999999808013
#  q2     = 44.14000000380505
#  etac   = 0.000608873286122615
#  alphac = 0.0006088732861226137
#
# df:
# 6271×26 DataFrame
#   Row │ index  name       kind        s        beta1       phi1       dx       ⋯
#       │                               [m]      [m]         [2π]       [m]      ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │     1  IP6        Marker         0.0     0.589999   0.0        4.74366 ⋯
#     2 │     2  DRIFT0     Drift          0.0     0.589999   0.0        4.74366
#     3 │     3  Q1ER_6     Quadrupole     5.3    48.2002     0.232355   6.01291
#     4 │     4  DRIFT1     Drift          7.1   151.952      0.236135   1.05195
#     5 │     5  Q2ER_6     Quadrupole     7.6   220.652      0.236569   1.26542 ⋯
#     6 │     6  DRIFT2     Drift          9.0   333.073      0.237332   1.5499e
#     7 │     7  D2ER_6     SBend         16.75  233.455      0.241756   1.27366
# ...

# %% [markdown]
# To see what properties `tw` has, use `propertynames`:

# %%
print(propertynames(tw))
# Out:
# [:q1, :q2, :etac, :alphac, :index, :name, :kind, :s, :beta1, :phi1, :dx, :x, :beta2, :phi2, :dy, :y, :slip, :alpha1, :alpha2, :px, :py, :z, :pz, :dpx, :dpy, :gammac, :c11, :c12, :c21, :c22]

# %% [markdown]
# The output columns of `twiss` can be customized using the `cols` keyword argument. For all possible columns, see `??twiss`.
#
# We can plot the betas:

# %%
f = Figure(fontsize=22, size=(800,500));
ax = Axis(f[1, 1], xlabel="s [m]", ylabel="Beta Function [m]");
lines!(ax, tw.s, tw.beta1, label=L"\beta_1"); # L".." specifies a LaTeX string
lines!(ax, tw.s, tw.beta2, label=L"\beta_2");
axislegend(position=:rt);
display(f);

# %% [markdown]
# Note that the plot shows $\beta_1$ and $\beta_2$ using a Teng-Edwards coupling formalism.
#
# The closed orbit can be accessed from fields `x`, `px`, `y`, `py`, `z`, and `pz`, and the periodic dispersion can be obtained from `dx`, `dpx`, `dy`, and `dpy`. The syntax `d<column>_<order>` can be used for _any_ scalar-valued to take a chromatic derivative, and by omitting `_<order>` the order is assumed to be 1.

# %%
f = Figure(fontsize=22, size=(800,500));
ax = Axis(f[1, 1], xlabel="s [m]", ylabel="Dispersion [m]");
lines!(ax, tw.s, tw.dx, label=L"\eta_x"); # L".." specifies a LaTeX string
lines!(ax, tw.s, tw.dy, label=L"\eta_y");
axislegend(position=:rt);
display(f);

# %% [markdown]
# Higher order chromatic quantities can be computed by setting the chromatic order `chrom` appropriately, and requesting the corresponding column in the `twiss` result using `cols`. E.g., to get the second order dispersions $\frac{\partial^2x}{\partial\delta^2}$, $\frac{\partial^2y}{\partial\delta^2}$ as well as the chromatic beta beat $\frac{\partial\beta_1}{\partial\delta}$, $\frac{\partial\beta_2}{\partial\delta}$:

# %%
tw2 = twiss(ring; cols=["dx_2", "dy_2", "beta1", "dbeta1", "beta2", "dbeta2"], chrom=2)
# Out:
# Twiss:
# summ:
#  q1     = 48.07999999808019 + 1.0002256005657928 δ
#  q2     = 44.14000000380508 + 0.9998145974907912 δ
#  etac   = 0.0006088732861226299 + 0.0011325508462984035 δ
#  alphac = 0.0006088732861226285 + 0.0011325508462984011 δ
#
# df:
# 6271×10 DataFrame
#   Row │ index  name       kind        s        dx_2        dy_2         beta1  ⋯
#       │                               [m]                               [m]    ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │     1  IP6        Marker         0.0     -6.98496   2.44576e-5    0.58 ⋯
#     2 │     2  DRIFT0     Drift          0.0     -6.98496   2.44576e-5    0.58
#     3 │     3  Q1ER_6     Quadrupole     5.3     16.294     0.00218448   48.20
#     4 │     4  DRIFT1     Drift          7.1     31.677     0.00206566  151.95
#     5 │     5  Q2ER_6     Quadrupole     7.6     38.5511    0.00180003  220.65 ⋯
# ...

# %% [markdown]
# Note the chromaticities have also been computed

# %%
f = Figure(fontsize=22, size=(800,500));
ax = Axis(f[1, 1], xlabel="s [m]", ylabel="Second Order Dispersion [m]");
lines!(ax, tw2.s, tw2.dx_2, label=L"\partial_\delta\eta_x"); # L".." specifies a LaTeX string
lines!(ax, tw2.s, tw2.dy_2, label=L"\partial_\delta\eta_y");
axislegend(position=:rt);
display(f);

# %%
f = Figure(fontsize=22, size=(800,500));
ax = Axis(f[1, 1], xlabel="s [m]", ylabel="Chromatic Beta-Beat");
lines!(ax, tw2.s, tw2.dbeta1 ./ tw2.beta1, label=L"\partial_\delta\beta_1"); # L".." specifies a LaTeX string
lines!(ax, tw2.s, tw2.dbeta2 ./ tw2.beta2, label=L"\partial_\delta\beta_2");
axislegend(position=:rt);
display(f);

# %% [markdown]
# We can also write the Montague functions, which are phase invariants in achromatic regions, as
#
# $$
# W = \sqrt{A^2+B^2} \ , \ A=\frac{\partial\alpha}{\partial\delta}-\frac{\alpha}{\beta}\frac{\partial\beta}{\partial\delta} \ , \ B=\frac{1}{\beta}\frac{\partial\beta}{\partial\delta} \ .
# $$

# %%
tww = twiss(ring; cols=["w1", "w2"], chrom=2)
# Out:
# Twiss:
# summ:
#  q1     = 48.07999999808019 + 1.0002256005657928 δ
#  q2     = 44.14000000380508 + 0.9998145974907912 δ
#  etac   = 0.0006088732861226299 + 0.0011325508462984035 δ
#  alphac = 0.0006088732861226285 + 0.0011325508462984011 δ
#
# df:
# 6271×6 DataFrame
#   Row │ index  name       kind        s        w1        w2
#       │                               [m]      [1]       [1]
# ──────┼───────────────────────────────────────────────────────────
#     1 │     1  IP6        Marker         0.0    9.45204   13.0033
#     2 │     2  DRIFT0     Drift          0.0    9.45204   13.0033
#     3 │     3  Q1ER_6     Quadrupole     5.3   16.8513    90.6617
#     4 │     4  DRIFT1     Drift          7.1   34.6455   105.254
#     5 │     5  Q2ER_6     Quadrupole     7.6   47.3487   119.527
#     6 │     6  DRIFT2     Drift          9.0   59.043    132.949
#     7 │     7  D2ER_6     SBend         16.75  60.1801   133.811
#   ⋮   │   ⋮        ⋮          ⋮          ⋮        ⋮         ⋮
# ...

# %%
f = Figure(fontsize=22, size=(800,500));
ax = Axis(f[1, 1], xlabel="s [m]", ylabel="Montague Function");
lines!(ax, tww.s, tww.w1, label=L"W_1"); # L".." specifies a LaTeX string
lines!(ax, tww.s, tww.w2, label=L"W_2");
axislegend(position=:rt);
display(f);

# %% [markdown]
# Using the operator notation, the Bengtsson polynomial is defined as the polynomial $h$ in
#
# $$
# \mathcal{M} = \mathcal{A}_{cs}^{-1}\exp{(: h : )} \mathcal{R} \mathcal{A}_{cs}
# $$
#
# where $\mathcal{M}$ is the compositional operator representing the one turn map and $\mathcal{A}_{cs}$ is the compositional operator representing only a linear (Courant Snyder) normalizing transformation. Monomials of $h$ are sometimes referred to as "resonance driving terms" and "detune coefficients".
#
# We can extract any Bengtsson monomial by simply setting the `order` of `twiss` appropriately (must be at least one less than the total order of the monomial). And, if the beam is coasting, we can take chromatic derivatives.
#
# For example to compute $\frac{\partial h_{2000}}{\partial\delta}$:

# %%
twh = twiss(ring; cols=["dh2000"], order=2)
# Out:
# Twiss:
# summ:
#  q1     = 48.07999999808011 + 1.0002255976890106 δ
#  q2     = 44.14000000380504 + 0.9998145974910121 δ
#  etac   = 0.000608873286122615 + 0.0011325508462984059 δ
#  alphac = 0.0006088732861226137 + 0.0011325508462984035 δ
#
# df:
# 6271×5 DataFrame
#   Row │ index  name       kind        s        dh2000
#       │                               [m]
# ──────┼────────────────────────────────────────────────────────────
#     1 │     1  IP6        Marker         0.0    1.48729-4.30386im
#     2 │     2  DRIFT0     Drift          0.0    1.48729-4.30386im
#     3 │     3  Q1ER_6     Quadrupole     5.3     2.3634+7.76657im
#     4 │     4  DRIFT1     Drift          7.1    6.61346+15.3245im
#     5 │     5  Q2ER_6     Quadrupole     7.6    9.63809+20.6742im
#     6 │     6  DRIFT2     Drift          9.0    12.3038+25.6454im
#     7 │     7  D2ER_6     SBend         16.75   10.9514+26.844im
#   ⋮   │   ⋮        ⋮          ⋮          ⋮              ⋮
# ...

# %%
f = Figure(fontsize=22, size=(800,500));
ax = Axis(f[1, 1], xlabel="s [m]");
lines!(ax, twh.s, abs.(twh.dh2000), label=L"|\partial h_{2000}/\partial\delta|");
axislegend(position=:rt);
display(f);

# %% [markdown]
# Notice that this looks quite a lot like the Montague function - this is correct, and can be intuitively understood because $h_{2000}$ quantifies the beta-beating oscillating at $2\times$ the betatron frequency, and $\partial h_{2000}/\partial\delta$ describes how that depends on $\delta$.
#
# Of course we can also look at geometric terms:

# %%
twh2 = twiss(ring, cols=["h3000", "h2100", "h1020", "h1101", "h1002"], order=2)
f = Figure(fontsize=22, size=(800,500));
ax = Axis(f[1, 1], xlabel="s [m]");
lines!(ax, twh2.s, abs.(twh2.h3000), label=L"|\partial h_{h3000}/\partial\delta|");
lines!(ax, twh2.s, abs.(twh2.h2100), label=L"|\partial h_{h2100}/\partial\delta|");
lines!(ax, twh2.s, abs.(twh2.h1020), label=L"|\partial h_{h1020}/\partial\delta|");
lines!(ax, twh2.s, abs.(twh2.h1101), label=L"|\partial h_{h1101}/\partial\delta|");
lines!(ax, twh2.s, abs.(twh2.h1002), label=L"|\partial h_{h1002}/\partial\delta|");
axislegend(position=:rt);
display(f);

# %% [markdown]
# Because the sextupoles in the arcs have been arranged in $-I$ pairs, the geometric terms cancel themselves locally.
#
# Spin analysis is also provided in `twiss`, by setting `spin=true`.

# %%
tws = twiss(ring; spin=true)
f = Figure(fontsize=22, size=(800,500));
ax = Axis(f[1, 1], xlabel="s [m]");
lines!(ax, tws.s, tws.dnx, label=L"\partial n_x/\partial\delta");
lines!(ax, tws.s, tws.dny, label=L"\partial n_y/\partial\delta");
lines!(ax, tws.s, tws.dnz, label=L"\partial n_z/\partial\delta");
dn_amp = @. sqrt(tws.dnx^2 + tws.dny^2 + tws.dnz^2)
lines!(ax, tws.s, dn_amp, label=L"|\partial \hat{n}/\partial\delta|");
axislegend(position=:rt);
display(f);

# %% [markdown]
# Also note the (amplitude-dependent) spin tune will be calculated:

# %%
tws.qspin
# Out:
# AmplitudeDependentValue:
#  -0.49999977786392413 - 39.999999736788304 δ

# %% [markdown]
# For higher order tunes, set the order higher:

# %%
twtune = twiss(ring; at=[], spin=true, order=3); # at=[] means only compute tunes
twtune.qspin
# Out:
# AmplitudeDependentValue:
#  -0.4999997778639254 - 39.99999973678759 δ - 0.05100199836722927 J₁ + 2377.9907496227306 J₂ - 1.5845346022220614 δ² + 248.27884691534697 δ J₁ + 245185.47417557501 δ J₂ + 468.7335928736513 δ³

# %% [markdown]
# To get a particular term in the Taylor series, use the function `getterm`:

# %%
getterm(twtune.qspin, delta=1, J1=1)
# Out:
# 248.27884691534697

# %% [markdown]
# Finally, ,more advanced users who have become familiar with [`GTPSA.jl`](https://bmad-sim.github.io/GTPSA.jl/stable/quickstart/) can get the output as Taylor series by setting the flag `as_taylor_series=true`. A custom GTPSA descriptor can also be provided with `GTPSA_descriptor` for doing parametric normal form analysis (see the `orbit-response.ipynb` example notebook).

# %%
twisf = twiss(ring; at=[1], cols=["nx","ny","nz"], spin=true, as_taylor_series=true)
n = [twisf.nx[1], twisf.ny[1], twisf.nz[1]]
# Out:
# 3-element Vector{TPS64{GTPSA.Dynamic}}:
# Descriptor(NV=6, MO=1)
# INDEX  COEFFICIENT             ORDER   EXPONENTS
# ----------------------------------------------------
#   1:   4.4259785984435550E-15    0     0 0  0 0  0 0
#   1:   2.9437795672188072E-04    1     1 0  0 0  0 0
#   1:  -4.1507516882558363E+01    1     0 1  0 0  0 0
#   1:  -3.3567033718984669E+02    1     0 0  1 0  0 0
#   1:  -3.1223550771319215E+00    1     0 0  0 1  0 0
#   1:  -4.7133859854545496E-09    1     0 0  0 0  0 1
# ----------------------------------------------------
#   2:   1.9500184800236298E-10    0     0 0  0 0  0 0
#   2:  -1.3657465546521142E-04    1     1 0  0 0  0 0
#   2:   1.2501396826454069E-04    1     0 1  0 0  0 0
#   2:  -5.6419852071733516E+01    1     0 0  1 0  0 0
#   2:  -2.4600820432436628E+01    1     0 0  0 1  0 0
#   2:  -1.5707985193798670E+00    1     0 0  0 0  0 1
# ----------------------------------------------------
#   3:  -1.0000000000000000E+00    0     0 0  0 0  0 0
# ...
