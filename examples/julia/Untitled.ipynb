# %%
using SciBmad

# %%
qf = Quadrupole(Kn1=0.4, L=0.5)
sf = Sextupol
# Out:
# LoadError: MethodError: no method matching var"@elements"(::LineNumberNode, ::Module)
#
# Closest candidates are:
#   var"@elements"(::LineNumberNode, ::Module, ::Any)
#    @ Beamlines ~/.julia/dev/Beamlines/src/element-name-handling.jl:1
#
# in expression starting at In[2]:1
